# %%
import dill as pickle

# %%
try:
    with open('mcts_tictactoe.pkl', 'rb') as f:
        agent = pickle.load(f)
    print("Agent loaded successfully!")
except FileNotFoundError:
    print("Error: File mcts_tictactoe.pkl not found!")
except Exception as e:
    print(f"Error loading pickle file: {e}")
# Out:
# Agent loaded successfully!

# %%
type(agent)
# Out:
# __main__.MCTSAgent

# %%
agent.get_action()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ks/p3kfkbnx1bx8sbh3p9z_0d540000gn/T/ipykernel_77674/3537407301.py in <module>
# ----> 1 agent.get_action()
#
# TypeError: get_action() missing 1 required positional argument: 'game'

# %%
for state_key, actions_dict in agent.q_table.items():
    print(state_key)
    print(actions_dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ks/p3kfkbnx1bx8sbh3p9z_0d540000gn/T/ipykernel_77674/1026345710.py in <module>
# ----> 1 for state_key, actions_dict in agent.q_table.items():
#       2     print(state_key)
#       3     print(actions_dict)
#
# AttributeError: 'MCTSAgent' object has no attribute 'q_table'

# %%
for state_key, actions_dict in agent.q_table.items():
    print(state_key)
    print(actions_dict)
